# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading DataSet

# %%
federer=pd.read_csv(r"C:\Users\Vampatapu Koushik\handson\code\data\federer.csv")

# %%
federer.head()
# Out:
#    year           tournament  start date type        surface      draw  \
# 0  1998   Basel, Switzerland  05.10.1998   WS   Indoor: Hard  Draw: 32
# 1  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 2  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 3  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 4  1998  Geneva, Switzerland  24.08.1998   CH  Outdoor: Clay  Draw: 32
#
#   atp points  atp ranking tournament prize money round  ...  \
# 0          1        396.0                 $9,800   R32  ...
# 1         59        878.0                $10,800   R32  ...
# 2         59        878.0                $10,800   R16  ...
# 3         59        878.0                $10,800     Q  ...
# 4          1        680.0                   $520   R32  ...
#
#   player2 2nd serve return points total player2 break points converted won  \
# 0                                  22.0                                4.0
# ...

# %%
federer
# Out:
#       year                  tournament  start date type        surface  \
# 0     1998          Basel, Switzerland  05.10.1998   WS   Indoor: Hard
# 1     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 2     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 3     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 4     1998         Geneva, Switzerland  24.08.1998   CH  Outdoor: Clay
# ...    ...                         ...         ...  ...            ...
# 1174  2012  Australian Open, Australia  16.01.2012   GS  Outdoor: Hard
# 1175  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1176  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1177  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1178  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
#
#            draw atp points  atp ranking tournament prize money round  ...  \
# ...

# %%
federer.shape
# Out:
# (1179, 70)

# %% [markdown]
# # Percentage of matches won by Roger Federer

# %%
matches=federer.shape[0]
matches_won=federer[federer['winner']=='Roger Federer'].shape[0]
win_percentage=(matches_won/matches)*100
print(f"Percentage of matches won by Roger Federer: {win_percentage:.2f}%")
# Out:
# Percentage of matches won by Roger Federer: 82.44%

# %% [markdown]
# # Proportion of Double Faults Relative to Total Points

# %%
federer['Double_faults']=federer['player1 double faults']/federer['player1 total points total']
Double_faults=federer['Double_faults']
print(Double_faults)
# Out:
# 0       0.019417
# 1       0.000000
# 2       0.020270
# 3       0.046154
# 4            NaN
#           ...
# 1174    0.018116
# 1175    0.000000
# 1176    0.000000
# 1177    0.011561
# 1178         NaN
# Name: Double_faults, Length: 1179, dtype: float64

# %% [markdown]
# # Average win per surface

# %%
Avg_wps=federer[federer['winner']=='Roger Federer'].groupby('surface').size()
print(Avg_wps)
# Out:
# surface
# Indoor: Carpet     56
# Indoor: Clay        5
# Indoor: Hard      189
# Outdoor: Clay     194
# Outdoor: Grass    122
# Outdoor: Hard     406
# dtype: int64

# %% [markdown]
# # Proportion of Double Faults as a Function of Tournament Date ('start date')

# %%
federer['start date']=pd.to_datetime(federer['start date'],errors='coerce')
federer['year']=federer['start date'].dt.year
Avg_df_by_year=federer.groupby('year')['double_faults_proportion'].mean()
print(Avg_df_by_year)
# Out:
# year
# 1998.0    0.020738
# 1999.0    0.028285
# 2000.0    0.020918
# 2001.0    0.016780
# 2002.0    0.016084
# 2003.0    0.018211
# 2004.0    0.012856
# 2005.0    0.008778
# 2006.0    0.008495
# 2007.0    0.009116
# 2008.0    0.005306
# 2009.0    0.008313
# 2010.0    0.009711
# 2011.0    0.008275
# 2012.0    0.011024
# Name: double_faults_proportion, dtype: float64

# %% [markdown]
# # Based on the analysis of the Federer dataset,here are the key inference drawn from the data:
# ## ->Match Win Percentage:
# 1. Roger Federer has a high win percentage across his career.
# ## ->Performance on different surfaces:
# 1. Federer’s performance varies across surfaces. Typically, his strongest surface is grass,particularly at Wimbledon, where he has won the most titles.
# 2. On hard courts, Federer has also performed consistently well, winning many titles at the Australian Open and US Open.
# 3. His performance on clay courts, while strong, might not have been as dominant as on         other surfaces.
# ## ->Double faults:
# 1. The proportion of double faults across matches gives an insight into his serving            performance and confidence.
# 2. A consistent or low proportion of double faults over the years would suggest that           Federer has maintained a high level of service reliability throughout his career.
# ## ->Overall Inference:
# 1. Federer’s performance is highly consistent, reflecting his status as one of the greatest    tennis players of all time.
